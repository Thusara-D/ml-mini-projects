# %%
# !pwd
# Out:
# /content

# %%
# !git clone https://github.com/Thusara-D/ml-mini-projects.git
# Out:
# Cloning into 'ml-mini-projects'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 6.50 KiB | 6.50 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# !ls
# Out:
# ml-mini-projects  sample_data

# %%
# %cd ml-mini-projects
# Out:
# /content/ml-mini-projects

# %%
# %cd house-price-prediction
# Out:
# /content/ml-mini-projects/house-price-prediction

# %%
# !pwd
# !ls
# Out:
# /content/ml-mini-projects/house-price-prediction
# README.md

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive -name "Untitled19.ipynb"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Untitled19.ipynb

# %%
import shutil, os

# Change this filename to your current notebook name shown on top (e.g., Untitled17.ipynb)
current_nb = "/content/Untitled19.ipynb"

# Target location inside the repo folder
target_nb = "/content/ml-mini-projects/house-price-prediction/house_price_prediction.ipynb"

shutil.copy(current_nb, target_nb)
print("Copied to:", target_nb)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-781085692.py in <cell line: 0>()
#       7 target_nb = "/content/ml-mini-projects/house-price-prediction/house_price_prediction.ipynb"
#       8
# ----> 9 shutil.copy(current_nb, target_nb)
#      10 print("Copied to:", target_nb)
#
# /usr/lib/python3.12/shutil.py in copy(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copymode(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
#     261             try:
# ...
