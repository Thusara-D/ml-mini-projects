# %% [markdown]
# <a href="https://colab.research.google.com/github/Thusara-D/ml-mini-projects/blob/main/house_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
